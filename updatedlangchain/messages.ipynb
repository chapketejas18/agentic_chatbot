# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")



from langchain.chat_models import init_chat_model
model = init_chat_model("google_genai:gemini-2.5-flash-lite")

# %%
model.invoke("What is langchain?")
# Out:
# AIMessage(content="Langchain is a **framework for developing applications powered by large language models (LLMs)**. It's designed to make it easier to build complex LLM applications by providing a modular and composable set of tools and abstractions.\n\nThink of it as a toolkit that helps you connect LLMs to other sources of data and allows them to interact with their environment. Instead of just sending a prompt to an LLM and getting a single response, Langchain enables you to build more sophisticated workflows.\n\nHere's a breakdown of what that means and why it's useful:\n\n**Key Concepts and Components of Langchain:**\n\n*   **LLM Integration:** Langchain provides a standardized interface to interact with various LLMs (like OpenAI's GPT models, Anthropic's Claude, Hugging Face models, etc.). This means you can easily swap out LLMs in your application without major code changes.\n\n*   **Prompt Management:** Crafting effective prompts is crucial for LLMs. Langchain offers tools for:\n    *   **Prompt Templates:** Pre-defined structures for prompts that can be dynamically filled with variables.\n    *   **Output Parsers:** Tools to extract structured information from LLM outputs (e.g., JSON, lists, specific data types).\n\n*   **Chains:** This is a core concept in Langchain. Chains allow you to **sequence multiple LLM calls or other components together**. For example, you could have a chain that:\n    1.  Takes user input.\n    2.  Uses an LLM to summarize the input.\n    3.  Uses another LLM to answer a question based on the summary.\n    4.  Formats the final answer.\n\n*   **Agents:** Agents are more advanced than chains. They use an LLM to **decide which actions to take and in what order**. This involves:\n    *   **Tools:** LLM-compatible functions that agents can call (e.g., search engines, databases, calculators, APIs).\n    *   **Agent Executor:** The logic that orchestrates the agent's actions, allowing it to reason, plan, and execute tasks.\n\n*   **Memory:** LLMs are typically stateless. Langchain provides mechanisms to **give LLMs memory**, allowing them to recall previous interactions within a conversation. This is essential for building chatbots and conversational agents.\n\n*   **Document Loaders:** Tools to load data from various sources (e.g., PDFs, websites, databases, Notion) into a format that LLMs can process.\n\n*   **Text Splitters:** LLMs have context window limitations. Text splitters help break down large documents into smaller, manageable chunks for processing.\n\n*   **Vector Stores and Embeddings:** Langchain integrates with vector databases (like Chroma, Pinecone, FAISS) and embedding models to enable **semantic search and retrieval-augmented generation (RAG)**. This allows LLMs to access and reason over large amounts of external knowledge.\n\n**Why is Langchain Important?**\n\n*   **Simplifies LLM Development:** It abstracts away much of the boilerplate code and complexity involved in working with LLMs, allowing developers to focus on building application logic.\n*   **Enables Complex Workflows:** It empowers developers to create sophisticated applications that go beyond simple Q&A, such as:\n    *   **Chatbots with memory and access to external data.**\n    *   **Question-answering systems over large document sets.**\n    *   **Data analysis and summarization tools.**\n    *   **Automated agents that can perform tasks.**\n*   **Modularity and Composability:** The framework is designed with modularity in mind, making it easy to combine different components and build custom solutions.\n*   **Rapid Prototyping:** Langchain accelerates the prototyping process for LLM-powered applications.\n*   **Growing Ecosystem:** It has a vibrant community and is rapidly evolving with new integrations and features.\n\n**In essence, Langchain acts as a bridge between the raw power of LLMs and the practical needs of building real-world applications.** It provides the structure and tools to make LLMs more useful, ...

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage, ToolMessage

system_msg = SystemMessage("""
You are senior python developer with expertise in web framworks. Answer the question as concisely as possible.
""")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# You can create a REST API using Python web frameworks like Flask or Django.
#
# **Flask:**
#
# 1.  **Install Flask:**
#     ```bash
#     pip install Flask
#     ```
# 2.  **Create a simple app:**
#     ```python
#     from flask import Flask, jsonify, request
#
#     app = Flask(__name__)
#
#     @app.route('/api/data', methods=['GET'])
#     def get_data():
#         return jsonify({"message": "Hello, REST API!"})
#
#     @app.route('/api/data', methods=['POST'])
#     def create_data():
#         new_data = request.get_json()
#         return jsonify({"received": new_data}), 201 # 201 Created
#
#     if __name__ == '__main__':
#         app.run(debug=True)
#     ```
#
# **Django:**
#
# 1.  **Install Django and Django REST Framework:**
#     ```bash
#     pip install Django djangorestframework
#     ```
# 2.  **Set up a Django project and app.**
# 3.  **Define a model (e.g., `models.py`):**
#     ```python
#     from django.db import models
#
#     class Item(models.Model):
#         name = models.CharField(max_length=100)
#         description = models.TextField()
#     ```
# 4.  **Create a serializer (e.g., `serializers.py`):**
#     ```python
#     from rest_framework import serializers
#     from .models import Item
#
#     class ItemSerializer(serializers.ModelSerializer):
#         class Meta:
#             model = Item
#             fields = '__all__'
#     ```
# 5.  **Create a viewset (e.g., `views.py`):**
#     ```python
#     from rest_framework import viewsets
#     from .models import Item
#     from .serializers import ItemSerializer
#
#     class ItemViewSet(viewsets.ModelViewSet):
#         queryset = Item.objects.all()
#         serializer_class = ItemSerializer
#     ```
# 6.  **Configure URLs (e.g., `urls.py` in your app):**
#     ```python
#     from django.urls import path, include
#     from rest_framework.routers import DefaultRouter
#     from .views import ItemViewSet
#
#     router = DefaultRouter()
#     router.register(r'items', ItemViewSet)
#
#     urlpatterns = [
#         path('', include(router.urls)),
#     ]
#     ```
# 7.  **Include app URLs in project `urls.py`.**
#
# Both frameworks allow you to define routes (endpoints), handle HTTP methods (GET, POST, PUT, DELETE), and return data in formats like JSON.
